# %%
import os
for dirname, _, filenames in os.walk('/Users/pulin05/kaggling/kaggling/Competitions'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /Users/pulin05/kaggling/kaggling/Competitions/.DS_Store
# /Users/pulin05/kaggling/kaggling/Competitions/Playground series/.DS_Store
# /Users/pulin05/kaggling/kaggling/Competitions/Playground series/Predicting-heart-disease/.DS_Store
# /Users/pulin05/kaggling/kaggling/Competitions/Playground series/Predicting-heart-disease/heart-disease.ipynb
# /Users/pulin05/kaggling/kaggling/Competitions/Playground series/Predicting-heart-disease/PLAN.md
# /Users/pulin05/kaggling/kaggling/Competitions/Playground series/Predicting-heart-disease/Dataset/test.csv
# /Users/pulin05/kaggling/kaggling/Competitions/Playground series/Predicting-heart-disease/Dataset/train.csv
# /Users/pulin05/kaggling/kaggling/Competitions/Playground series/Predicting-heart-disease/Dataset/sample_submission.csv
# /Users/pulin05/kaggling/kaggling/Competitions/AI Mathematical Olympiad/.DS_Store
# /Users/pulin05/kaggling/kaggling/Competitions/AI Mathematical Olympiad/PLAN.md
# ...
